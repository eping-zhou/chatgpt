# %%
import pandas as pd

df1 = pd.read_csv('https://query.data.world/s/pynwnu66hvj42l7a7ez7t22l2lgx45?dws=00000',skiprows=1)

df1.head(5)
# Out:
# /var/folders/29/fz_gk_4916z9q33h2hddv78w0000gn/T/ipykernel_2665/3081303159.py:3: DtypeWarning: Columns (0,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('https://query.data.world/s/pynwnu66hvj42l7a7ez7t22l2lgx45?dws=00000',skiprows=1)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599.0     5000.0       5000.0           4975.0   36 months
# 1  1077430  1314167.0     2500.0       2500.0           2500.0   60 months
# 2  1077175  1313524.0     2400.0       2400.0           2400.0   36 months
# 3  1076863  1277178.0    10000.0      10000.0          10000.0   36 months
# 4  1075358  1311748.0     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# ...

# %%
df1.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599.0     5000.0       5000.0           4975.0   36 months
# 1  1077430  1314167.0     2500.0       2500.0           2500.0   60 months
# 2  1077175  1313524.0     2400.0       2400.0           2400.0   36 months
# 3  1076863  1277178.0    10000.0      10000.0          10000.0   36 months
# 4  1075358  1311748.0     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df1['issue_d'].unique()
# Out:
# array(['Dec-2011', 'Nov-2011', 'Oct-2011', 'Sep-2011', 'Aug-2011',
#        'Jul-2011', 'Jun-2011', 'May-2011', 'Apr-2011', 'Mar-2011',
#        'Feb-2011', 'Jan-2011', 'Dec-2010', 'Nov-2010', 'Oct-2010',
#        'Sep-2010', 'Aug-2010', 'Jul-2010', 'Jun-2010', 'May-2010',
#        'Apr-2010', 'Mar-2010', 'Feb-2010', 'Jan-2010', 'Dec-2009',
#        'Nov-2009', 'Oct-2009', 'Sep-2009', 'Aug-2009', 'Jul-2009',
#        'Jun-2009', 'May-2009', 'Apr-2009', 'Mar-2009', 'Feb-2009',
#        'Jan-2009', 'Dec-2008', 'Nov-2008', 'Oct-2008', 'Sep-2008',
#        'Aug-2008', 'Jul-2008', 'Jun-2008', 'May-2008', 'Apr-2008',
#        'Mar-2008', 'Feb-2008', 'Jan-2008', 'Dec-2007', 'Nov-2007',
#        'Oct-2007', 'Sep-2007', 'Aug-2007', 'Jul-2007', 'Jun-2007', nan],
#       dtype=object)

# %%
df1['issue_d'] = pd.to_datetime(df1['issue_d'], format='%b-%Y').dt.strftime('%Y-%m')

# %%
# Specify the file path and name for the CSV file
file_path = '/Users/yipingzhou/Chat-GPT/Lending.csv'

# Save the DataFrame to a CSV file
df1.to_csv(file_path, mode='w', index=False, float_format='%.0f')
